# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv

# %% [markdown]
# ## 1. Dataset 1 - Kenya_airways_flights

# %%
import pandas as pd

def inspect_dataframe(df):
    """
    This function takes a pandas DataFrame as input and prints the following:
    1. Info about the DataFrame (including data types and non-null counts)
    2. Shape of the DataFrame (number of rows and columns)
    3. Count of missing values per column
    4. Count of duplicate rows
    """
    # 1. Info about the DataFrame
    print("---- DataFrame Info ----")
    df.info()
    print("\n")
    
    # 2. Shape of the DataFrame
    print("---- DataFrame Shape ----")
    print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
    print("\n")
    
    # 3. Missing values per column
    print("---- Missing Values ----")
    missing_values = df.isnull().sum()
    print(missing_values[missing_values > 0])
    print("\n")
    
    # 4. Count of duplicate rows
    print("---- Duplicate Rows ----")
    duplicate_count = df.duplicated().sum()
    print(f"Number of duplicate rows: {duplicate_count}")
    print("\n")

# Example usage:
df = pd.read_csv("kenya_airways_flights (1).csv", delimiter=',', on_bad_lines='skip', encoding='utf-8')
inspect_dataframe(df)
# Out:
# ---- DataFrame Info ----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2362 entries, 0 to 2361
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           2362 non-null   object
#  1   Image           2239 non-null   object
#  2   Avatar_URL      2353 non-null   object
#  3   crvsd           2352 non-null   object
#  4   ui_header_link  2351 non-null   object
#  5   default         1855 non-null   object
#  6   phmbo           2352 non-null   object
#  7   phmbo1          2110 non-null   object
#  8   dmrsr           2350 non-null   object
#  9   dmrsr2          2350 non-null   object
#  10  dmrsr3          2348 non-null   object
#  11  qwuub_URL       2352 non-null   object
#  12  qwuub           2352 non-null   object
#  13  tehyy           2213 non-null   object
#  14  xcjrc           2352 non-null   object
#  15  Rating          2352 non-null   object
# dtypes: object(16)
# memory usage: 295.4+ KB
#
#
# ---- DataFrame Shape ----
# Rows: 2362, Columns: 16
#
#
# ---- Missing Values ----
# Image             123
# Avatar_URL          9
# crvsd              10
# ui_header_link     11
# default           507
# phmbo              10
# phmbo1            252
# dmrsr              12
# dmrsr2             12
# dmrsr3             14
# qwuub_URL          10
# qwuub              10
# tehyy             149
# xcjrc              10
# Rating             10
# dtype: int64
#
#
# ---- Duplicate Rows ----
# Number of duplicate rows: 17

# %%
df = pd.read_csv("kenya_airways_flights (1).csv", delimiter=',', on_bad_lines='skip', encoding='utf-8')
df.head(1)
# Out:
#                                                Title  \
# 0  Recently I travelled for business from Cape To...
#
#                                                Image  \
# 0  https://media-cdn.tripadvisor.com/media/photo-...
#
#                                     Avatar_URL  \
# 0  https://www.tripadvisor.com/Profile/dewaldr
#
#                               crvsd ui_header_link  \
# 0  Dewald R wrote a review Nov 2022       Dewald R
#
#                            default               phmbo             phmbo1  \
# 0  Cape Town Central, South Africa  2336 contributions  198 helpful votes
#
#                          dmrsr  dmrsr2   dmrsr3  \
# 0  Cape Town Central - Entebbe  Africa  Economy
#
#                                            qwuub_URL  \
# 0  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                       qwuub                           tehyy  \
# 0  Cape Town to Uganda via Nairobi and Back  Date of travel: September 2022
#
#                                                xcjrc  \
# 0  This review is the subjective opinion of a Tri...
#
#                        Rating
# 0  ui_bubble_rating bubble_40

# %%
# Dropping the duplicate rows
df = df.drop_duplicates()
df.reset_index(drop=True, inplace=True)

df
# Out:
#                                                   Title  \
# 0     Recently I travelled for business from Cape To...
# 1     I want to thanks to Jane for her excellent ser...
# 2     not a bad airline to fly with could do with a ...
# 3     Dear Kenya Airways ,\n\nI am on my way to Zanz...
# 4     Absolutely appalling airline, never ever use i...
# ...                                                 ...
# 2340  The flight was a good one. Staff are friendly ...
# 2341  It was an overnight flight so we managed to sl...
# 2342  Kenya Airways is by far the most acceptable fo...
# 2343  During our trip to South Africa we traveled fo...
# 2344  I flew 6 times with this airline and every tim...
#
#                                                   Image  \
# 0     https://media-cdn.tripadvisor.com/media/photo-...
# 1     https://media-cdn.tripadvisor.com/media/photo-...
# 2     https://media-cdn.tripadvisor.com/media/photo-...
# 3     https://media-cdn.tripadvisor.com/media/photo-...
# 4     https://media-cdn.tripadvisor.com/media/photo-...
# ...                                                 ...
# 2340  https://media-cdn.tripadvisor.com/media/photo-...
# 2341  https://media-cdn.tripadvisor.com/media/photo-...
# 2342  https://media-cdn.tripadvisor.com/media/photo-...
# 2343  https://media-cdn.tripadvisor.com/media/photo-...
# 2344  https://media-cdn.tripadvisor.com/media/photo-...
#
#                                              Avatar_URL  \
# 0           https://www.tripadvisor.com/Profile/dewaldr
# 1          https://www.tripadvisor.com/Profile/Alien555
# 2     https://www.tripadvisor.com/Profile/eddiepB8777IQ
# 3        https://www.tripadvisor.com/Profile/VirginieAn
# 4     https://www.tripadvisor.com/Profile/H5647LLjasonm
# ...                                                 ...
# 2340   https://www.tripadvisor.com/Profile/973christine
# 2341       https://www.tripadvisor.com/Profile/548pinam
# 2342      https://www.tripadvisor.com/Profile/147azhark
# 2343       https://www.tripadvisor.com/Profile/Ash_paul
# 2344      https://www.tripadvisor.com/Profile/rebe_cluj
#
#                                      crvsd ui_header_link  \
# 0         Dewald R wrote a review Nov 2022       Dewald R
# 1             Jose wrote a review Nov 2022           Jose
# 2          Eddie P wrote a review Nov 2022        Eddie P
# 3           Virg A wrote a review Nov 2022         Virg A
# 4          Jason M wrote a review Nov 2022        Jason M
# ...                                    ...            ...
# 2340  973christine wrote a review Jan 2016   973christine
# 2341        Pina M wrote a review Jan 2016         Pina M
# 2342       Azhar K wrote a review Jan 2016        Azhar K
# 2343      Ash_paul wrote a review Jan 2016       Ash_paul
# 2344     rebe_cluj wrote a review Jan 2016      rebe_cluj
#
#                               default               phmbo             phmbo1  \
# 0     Cape Town Central, South Africa  2336 contributions  198 helpful votes
# 1                                 NaN      1 contribution                NaN
# 2                       Cork, Ireland      1 contribution                NaN
# 3                                 NaN     6 contributions                NaN
# 4              London, United Kingdom    22 contributions    6 helpful votes
# ...                               ...                 ...                ...
# 2340                   Nairobi, Kenya    40 contributions    8 helpful votes
# 2341           London, United Kingdom   138 contributions   41 helpful votes
# 2342             Watamu, Coast, Kenya    74 contributions   21 helpful votes
# 2343                          Kolkata    56 contributions   28 helpful votes
# 2344        Southern Romania, Romania    19 contributions    7 helpful votes
#
#                                   dmrsr         dmrsr2          dmrsr3  \
# 0           Cape Town Central - Entebbe         Africa         Economy
# 1     New York City - Cape Town Central  International         Economy
# 2                      London - Nairobi  International         Economy
# 3              Bangui - Zanzibar Island         Africa  Business Class
# 4                    Entebbe - Lilongwe         Africa         Economy
# ...                                 ...            ...             ...
# 2340          Nairobi - Zanzibar Island         Africa         Economy
# 2341                  London - Victoria  International         Economy
# 2342                    Mombasa - Dubai  International         Economy
# 2343                   Mumbai - Nairobi  International         Economy
# 2344                  Kigali - Victoria         Africa         Economy
#
#                                               qwuub_URL  \
# 0     https://www.tripadvisor.com/ShowUserReviews-g1...
# 1     https://www.tripadvisor.com/ShowUserReviews-g1...
# 2     https://www.tripadvisor.com/ShowUserReviews-g1...
# 3     https://www.tripadvisor.com/ShowUserReviews-g1...
# 4     https://www.tripadvisor.com/ShowUserReviews-g1...
# ...                                                 ...
# 2340  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2341  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2342  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2343  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2344  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                                   qwuub  \
# 0              Cape Town to Uganda via Nairobi and Back
# 1     I wanted to try becuase I read the reviews but...
# 2                                  kenya airways review
# 3                                   Horrible experience
# 4                   Avoid this airline like a bargepole
# ...                                                 ...
# 2340                                       Good service
# 2341                           The staff is outstanding
# 2342                                 The best in Africa
# 2343                               Inconsistent service
# 2344                                The pride of Africa
#
#                                tehyy  \
# 0     Date of travel: September 2022
# 1      Date of travel: November 2022
# 2           Date of travel: May 2022
# 3      Date of travel: November 2022
# 4      Date of travel: November 2022
# ...                              ...
# 2340    Date of travel: October 2015
# 2341   Date of travel: November 2015
# 2342   Date of travel: November 2015
# 2343    Date of travel: January 2016
# 2344   Date of travel: December 2015
#
#                                                   xcjrc  \
# 0     This review is the subjective opinion of a Tri...
# 1     This review is the subjective opinion of a Tri...
# 2     This review is the subjective opinion of a Tri...
# 3     This review is the subjective opinion of a Tri...
# 4     This review is the subjective opinion of a Tri...
# ...                                                 ...
# 2340  This review is the subjective opinion of a Tri...
# 2341  This review is the subjective opinion of a Tri...
# 2342  This review is the subjective opinion of a Tri...
# 2343  This review is the subjective opinion of a Tri...
# 2344  This review is the subjective opinion of a Tri...
#
#                           Rating
# 0     ui_bubble_rating bubble_40
# 1     ui_bubble_rating bubble_50
# 2     ui_bubble_rating bubble_40
# 3     ui_bubble_rating bubble_10
# 4     ui_bubble_rating bubble_10
# ...                          ...
# 2340  ui_bubble_rating bubble_40
# 2341  ui_bubble_rating bubble_40
# 2342  ui_bubble_rating bubble_40
# 2343  ui_bubble_rating bubble_30
# 2344  ui_bubble_rating bubble_50
#
# [2345 rows x 16 columns]

# %%
df1 = df.drop(columns= ['Image', 'Avatar_URL', 'crvsd', 'ui_header_link', 'default', 'phmbo', 'phmbo1', 'dmrsr', 'qwuub_URL', 'xcjrc'])
df1
# Out:
#                                                   Title         dmrsr2  \
# 0     Recently I travelled for business from Cape To...         Africa
# 1     I want to thanks to Jane for her excellent ser...  International
# 2     not a bad airline to fly with could do with a ...  International
# 3     Dear Kenya Airways ,\n\nI am on my way to Zanz...         Africa
# 4     Absolutely appalling airline, never ever use i...         Africa
# ...                                                 ...            ...
# 2340  The flight was a good one. Staff are friendly ...         Africa
# 2341  It was an overnight flight so we managed to sl...  International
# 2342  Kenya Airways is by far the most acceptable fo...  International
# 2343  During our trip to South Africa we traveled fo...  International
# 2344  I flew 6 times with this airline and every tim...         Africa
#
#               dmrsr3                                              qwuub  \
# 0            Economy           Cape Town to Uganda via Nairobi and Back
# 1            Economy  I wanted to try becuase I read the reviews but...
# 2            Economy                               kenya airways review
# 3     Business Class                                Horrible experience
# 4            Economy                Avoid this airline like a bargepole
# ...              ...                                                ...
# 2340         Economy                                       Good service
# 2341         Economy                           The staff is outstanding
# 2342         Economy                                 The best in Africa
# 2343         Economy                               Inconsistent service
# 2344         Economy                                The pride of Africa
#
#                                tehyy                      Rating
# 0     Date of travel: September 2022  ui_bubble_rating bubble_40
# 1      Date of travel: November 2022  ui_bubble_rating bubble_50
# 2           Date of travel: May 2022  ui_bubble_rating bubble_40
# 3      Date of travel: November 2022  ui_bubble_rating bubble_10
# 4      Date of travel: November 2022  ui_bubble_rating bubble_10
# ...                              ...                         ...
# 2340    Date of travel: October 2015  ui_bubble_rating bubble_40
# 2341   Date of travel: November 2015  ui_bubble_rating bubble_40
# 2342   Date of travel: November 2015  ui_bubble_rating bubble_40
# 2343    Date of travel: January 2016  ui_bubble_rating bubble_30
# 2344   Date of travel: December 2015  ui_bubble_rating bubble_50
#
# [2345 rows x 6 columns]

# %%
df1['Review'] = df1['Title'] + ' ' + df1['qwuub']
df1 = df1.drop(columns= ['Title', 'qwuub'])
df1.head(5)
# Out:
#           dmrsr2          dmrsr3                           tehyy  \
# 0         Africa         Economy  Date of travel: September 2022
# 1  International         Economy   Date of travel: November 2022
# 2  International         Economy        Date of travel: May 2022
# 3         Africa  Business Class   Date of travel: November 2022
# 4         Africa         Economy   Date of travel: November 2022
#
#                        Rating  \
# 0  ui_bubble_rating bubble_40
# 1  ui_bubble_rating bubble_50
# 2  ui_bubble_rating bubble_40
# 3  ui_bubble_rating bubble_10
# 4  ui_bubble_rating bubble_10
#
#                                               Review
# 0  Recently I travelled for business from Cape To...
# 1  I want to thanks to Jane for her excellent ser...
# 2  not a bad airline to fly with could do with a ...
# 3  Dear Kenya Airways ,\n\nI am on my way to Zanz...
# 4  Absolutely appalling airline, never ever use i...

# %%
df1.rename(columns={'dmrsr2': 'Departures', 'dmrsr3': 'Class', 'tehyy': 'Date'}, inplace=True)
df1.head(5)
# Out:
#       Departures           Class                            Date  \
# 0         Africa         Economy  Date of travel: September 2022
# 1  International         Economy   Date of travel: November 2022
# 2  International         Economy        Date of travel: May 2022
# 3         Africa  Business Class   Date of travel: November 2022
# 4         Africa         Economy   Date of travel: November 2022
#
#                        Rating  \
# 0  ui_bubble_rating bubble_40
# 1  ui_bubble_rating bubble_50
# 2  ui_bubble_rating bubble_40
# 3  ui_bubble_rating bubble_10
# 4  ui_bubble_rating bubble_10
#
#                                               Review
# 0  Recently I travelled for business from Cape To...
# 1  I want to thanks to Jane for her excellent ser...
# 2  not a bad airline to fly with could do with a ...
# 3  Dear Kenya Airways ,\n\nI am on my way to Zanz...
# 4  Absolutely appalling airline, never ever use i...

# %%
missing_values = df1.isnull().sum()

# Display the number of missing values for each column
print(missing_values)
# Out:
# Departures     12
# Class          14
# Date          148
# Rating         10
# Review         10
# dtype: int64

# %%
# Fill missing values with a specific date
df1['Date'].fillna('2020-01-01', inplace=True)

df1.sample(5)
# Out:
#          Departures    Class                            Date  \
# 2102         Africa  Economy  Date of travel: September 2016
# 1430  International  Economy      Date of travel: April 2018
# 1541         Africa  Economy    Date of travel: January 2018
# 1050         Africa  Economy                      2020-01-01
# 1927         Africa  Economy      Date of travel: March 2017
#
#                           Rating  \
# 2102  ui_bubble_rating bubble_30
# 1430  ui_bubble_rating bubble_30
# 1541  ui_bubble_rating bubble_40
# 1050  ui_bubble_rating bubble_40
# 1927  ui_bubble_rating bubble_10
#
#                                                  Review
# 2102  Travelled with Kenya airways. My flight to Ken...
# 1430  Food service was pretty poor- about half of th...
# 1541  Friendly staff made this early morning flight ...
# 1050  We took this trip (return) at a reasonable pri...
# 1927  Our baggage was delayed on a flight from Kenya...

# %%
# Strip 'Date of travel: ' from the Date column
df1['Date'] = df1['Date'].str.replace('Date of travel: ', '');

df1.head(5)
# Out:
#       Departures           Class            Date                      Rating  \
# 0         Africa         Economy  September 2022  ui_bubble_rating bubble_40
# 1  International         Economy   November 2022  ui_bubble_rating bubble_50
# 2  International         Economy        May 2022  ui_bubble_rating bubble_40
# 3         Africa  Business Class   November 2022  ui_bubble_rating bubble_10
# 4         Africa         Economy   November 2022  ui_bubble_rating bubble_10
#
#                                               Review
# 0  Recently I travelled for business from Cape To...
# 1  I want to thanks to Jane for her excellent ser...
# 2  not a bad airline to fly with could do with a ...
# 3  Dear Kenya Airways ,\n\nI am on my way to Zanz...
# 4  Absolutely appalling airline, never ever use i...

# %%
# Convert to datetime, invalid parsing will be set as NaT
df1['Date3'] = pd.to_datetime(df1['Date'], errors='coerce')

# Display DataFrame with converted timestamps
df1
# Out:
# C:\Users\JEREMY\AppData\Local\Temp\ipykernel_54792\252761272.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['Date3'] = pd.to_datetime(df1['Date'], errors='coerce')
#          Departures           Class            Date  \
# 0            Africa         Economy  September 2022
# 1     International         Economy   November 2022
# 2     International         Economy        May 2022
# 3            Africa  Business Class   November 2022
# 4            Africa         Economy   November 2022
# ...             ...             ...             ...
# 2340         Africa         Economy    October 2015
# 2341  International         Economy   November 2015
# 2342  International         Economy   November 2015
# 2343  International         Economy    January 2016
# 2344         Africa         Economy   December 2015
#
#                           Rating  \
# 0     ui_bubble_rating bubble_40
# 1     ui_bubble_rating bubble_50
# 2     ui_bubble_rating bubble_40
# 3     ui_bubble_rating bubble_10
# 4     ui_bubble_rating bubble_10
# ...                          ...
# 2340  ui_bubble_rating bubble_40
# 2341  ui_bubble_rating bubble_40
# 2342  ui_bubble_rating bubble_40
# 2343  ui_bubble_rating bubble_30
# 2344  ui_bubble_rating bubble_50
#
#                                                  Review      Date3
# 0     Recently I travelled for business from Cape To... 2022-09-01
# 1     I want to thanks to Jane for her excellent ser... 2022-11-01
# 2     not a bad airline to fly with could do with a ... 2022-05-01
# 3     Dear Kenya Airways ,\n\nI am on my way to Zanz... 2022-11-01
# 4     Absolutely appalling airline, never ever use i... 2022-11-01
# ...                                                 ...        ...
# 2340  The flight was a good one. Staff are friendly ... 2015-10-01
# 2341  It was an overnight flight so we managed to sl... 2015-11-01
# 2342  Kenya Airways is by far the most acceptable fo... 2015-11-01
# 2343  During our trip to South Africa we traveled fo... 2016-01-01
# 2344  I flew 6 times with this airline and every tim... 2015-12-01
#
# [2345 rows x 6 columns]

# %%
# Set the 'Date' column as the index
df1.set_index('Date3', inplace=True)
df1
# Out:
#                Departures           Class            Date  \
# Date3
# 2022-09-01         Africa         Economy  September 2022
# 2022-11-01  International         Economy   November 2022
# 2022-05-01  International         Economy        May 2022
# 2022-11-01         Africa  Business Class   November 2022
# 2022-11-01         Africa         Economy   November 2022
# ...                   ...             ...             ...
# 2015-10-01         Africa         Economy    October 2015
# 2015-11-01  International         Economy   November 2015
# 2015-11-01  International         Economy   November 2015
# 2016-01-01  International         Economy    January 2016
# 2015-12-01         Africa         Economy   December 2015
#
#                                 Rating  \
# Date3
# 2022-09-01  ui_bubble_rating bubble_40
# 2022-11-01  ui_bubble_rating bubble_50
# 2022-05-01  ui_bubble_rating bubble_40
# 2022-11-01  ui_bubble_rating bubble_10
# 2022-11-01  ui_bubble_rating bubble_10
# ...                                ...
# 2015-10-01  ui_bubble_rating bubble_40
# 2015-11-01  ui_bubble_rating bubble_40
# 2015-11-01  ui_bubble_rating bubble_40
# 2016-01-01  ui_bubble_rating bubble_30
# 2015-12-01  ui_bubble_rating bubble_50
#
#                                                        Review
# Date3
# 2022-09-01  Recently I travelled for business from Cape To...
# 2022-11-01  I want to thanks to Jane for her excellent ser...
# 2022-05-01  not a bad airline to fly with could do with a ...
# 2022-11-01  Dear Kenya Airways ,\n\nI am on my way to Zanz...
# 2022-11-01  Absolutely appalling airline, never ever use i...
# ...                                                       ...
# 2015-10-01  The flight was a good one. Staff are friendly ...
# 2015-11-01  It was an overnight flight so we managed to sl...
# 2015-11-01  Kenya Airways is by far the most acceptable fo...
# 2016-01-01  During our trip to South Africa we traveled fo...
# 2015-12-01  I flew 6 times with this airline and every tim...
#
# [2345 rows x 5 columns]

# %%
# confirm missing values
missing_values = df1.isnull().sum()

# Display the number of missing values for each column
print(missing_values)
# Out:
# Departures    12
# Class         14
# Date           0
# Rating        10
# Review        10
# dtype: int64

# %%
# Define placeholders for each column
placeholders = {
    'Departures': 0,
    'Class': 'Unknown',
    'Rating': 0,
    'Review': 'No Review'
}

# Replace missing values with respective placeholders
Cleaned_df1 = df1.fillna(value=placeholders)

missing_values = Cleaned_df1.isnull().sum()

# Display the number of missing values for each column
print(missing_values)
# Out:
# Departures    0
# Class         0
# Date          0
# Rating        0
# Review        0
# dtype: int64

# %%
Cleaned_df1.head()
# Out:
#                Departures           Class            Date  \
# Date3
# 2022-09-01         Africa         Economy  September 2022
# 2022-11-01  International         Economy   November 2022
# 2022-05-01  International         Economy        May 2022
# 2022-11-01         Africa  Business Class   November 2022
# 2022-11-01         Africa         Economy   November 2022
#
#                                 Rating  \
# Date3
# 2022-09-01  ui_bubble_rating bubble_40
# 2022-11-01  ui_bubble_rating bubble_50
# 2022-05-01  ui_bubble_rating bubble_40
# 2022-11-01  ui_bubble_rating bubble_10
# 2022-11-01  ui_bubble_rating bubble_10
#
#                                                        Review
# Date3
# 2022-09-01  Recently I travelled for business from Cape To...
# 2022-11-01  I want to thanks to Jane for her excellent ser...
# 2022-05-01  not a bad airline to fly with could do with a ...
# 2022-11-01  Dear Kenya Airways ,\n\nI am on my way to Zanz...
# 2022-11-01  Absolutely appalling airline, never ever use i...

# %%
# Extract numeric rating from the 'Rating' column
Cleaned_df1['Rating_Value'] = Cleaned_df1['Rating'].str.extract('bubble_(\d+)')

# Convert the extracted values to numeric, replacing non-numeric values with NaN
Cleaned_df1['Rating_Value'] = pd.to_numeric(Cleaned_df1['Rating_Value'], errors='coerce')

# Scale the ratings from 20, 30, etc., to 2.0, 3.0, etc.
Cleaned_df1['Rating_Value'] = Cleaned_df1['Rating_Value'] / 10

# Optional: Update the rating description to fit the new scale
def rating_description(value):
    if pd.isna(value):
        return 'Unknown'
    if value >= 5.0:
        return 'Excellent'
    elif value >= 4.0:
        return 'Good'
    elif value >= 3.0:
        return 'Average'
    else:
        return 'Poor'

Cleaned_df1['Rating_Description'] = Cleaned_df1['Rating_Value'].apply(rating_description)

# Display the updated DataFrame
Cleaned_df1
# Out:
#                Departures           Class            Date  \
# Date3
# 2022-09-01         Africa         Economy  September 2022
# 2022-11-01  International         Economy   November 2022
# 2022-05-01  International         Economy        May 2022
# 2022-11-01         Africa  Business Class   November 2022
# 2022-11-01         Africa         Economy   November 2022
# ...                   ...             ...             ...
# 2015-10-01         Africa         Economy    October 2015
# 2015-11-01  International         Economy   November 2015
# 2015-11-01  International         Economy   November 2015
# 2016-01-01  International         Economy    January 2016
# 2015-12-01         Africa         Economy   December 2015
#
#                                 Rating  \
# Date3
# 2022-09-01  ui_bubble_rating bubble_40
# 2022-11-01  ui_bubble_rating bubble_50
# 2022-05-01  ui_bubble_rating bubble_40
# 2022-11-01  ui_bubble_rating bubble_10
# 2022-11-01  ui_bubble_rating bubble_10
# ...                                ...
# 2015-10-01  ui_bubble_rating bubble_40
# 2015-11-01  ui_bubble_rating bubble_40
# 2015-11-01  ui_bubble_rating bubble_40
# 2016-01-01  ui_bubble_rating bubble_30
# 2015-12-01  ui_bubble_rating bubble_50
#
#                                                        Review  Rating_Value  \
# Date3
# 2022-09-01  Recently I travelled for business from Cape To...           4.0
# 2022-11-01  I want to thanks to Jane for her excellent ser...           5.0
# 2022-05-01  not a bad airline to fly with could do with a ...           4.0
# 2022-11-01  Dear Kenya Airways ,\n\nI am on my way to Zanz...           1.0
# 2022-11-01  Absolutely appalling airline, never ever use i...           1.0
# ...                                                       ...           ...
# 2015-10-01  The flight was a good one. Staff are friendly ...           4.0
# 2015-11-01  It was an overnight flight so we managed to sl...           4.0
# 2015-11-01  Kenya Airways is by far the most acceptable fo...           4.0
# 2016-01-01  During our trip to South Africa we traveled fo...           3.0
# 2015-12-01  I flew 6 times with this airline and every tim...           5.0
#
#            Rating_Description
# Date3
# 2022-09-01               Good
# 2022-11-01          Excellent
# 2022-05-01               Good
# 2022-11-01               Poor
# 2022-11-01               Poor
# ...                       ...
# 2015-10-01               Good
# 2015-11-01               Good
# 2015-11-01               Good
# 2016-01-01            Average
# 2015-12-01          Excellent
#
# [2345 rows x 7 columns]

# %%
# Drop the original 'Rating' column 
Cleaned_df1 = Cleaned_df1.drop(columns=['Rating', 'Date'])   
Cleaned_df1
# Out:
#                Departures           Class  \
# Date3
# 2022-09-01         Africa         Economy
# 2022-11-01  International         Economy
# 2022-05-01  International         Economy
# 2022-11-01         Africa  Business Class
# 2022-11-01         Africa         Economy
# ...                   ...             ...
# 2015-10-01         Africa         Economy
# 2015-11-01  International         Economy
# 2015-11-01  International         Economy
# 2016-01-01  International         Economy
# 2015-12-01         Africa         Economy
#
#                                                        Review  Rating_Value  \
# Date3
# 2022-09-01  Recently I travelled for business from Cape To...           4.0
# 2022-11-01  I want to thanks to Jane for her excellent ser...           5.0
# 2022-05-01  not a bad airline to fly with could do with a ...           4.0
# 2022-11-01  Dear Kenya Airways ,\n\nI am on my way to Zanz...           1.0
# 2022-11-01  Absolutely appalling airline, never ever use i...           1.0
# ...                                                       ...           ...
# 2015-10-01  The flight was a good one. Staff are friendly ...           4.0
# 2015-11-01  It was an overnight flight so we managed to sl...           4.0
# 2015-11-01  Kenya Airways is by far the most acceptable fo...           4.0
# 2016-01-01  During our trip to South Africa we traveled fo...           3.0
# 2015-12-01  I flew 6 times with this airline and every tim...           5.0
#
#            Rating_Description
# Date3
# 2022-09-01               Good
# 2022-11-01          Excellent
# 2022-05-01               Good
# 2022-11-01               Poor
# 2022-11-01               Poor
# ...                       ...
# 2015-10-01               Good
# 2015-11-01               Good
# 2015-11-01               Good
# 2016-01-01            Average
# 2015-12-01          Excellent
#
# [2345 rows x 5 columns]

# %% [markdown]
# ##  Dataset 2 - Kenya_airways_reviews

# %%
df2 = pd.read_csv('kenya_airways_reviews.csv')
df2
# Out:
#                 Date                                             Review
# 0    3rd August 2024  ✅ Trip Verified | I have never seen such a dis...
# 1    2nd August 2024  Not Verified |   Bumped off flight at boarding...
# 2     30th July 2024  ✅ Trip Verified |   I am disappointment with t...
# 3     25th July 2024  ✅ Trip Verified |  This airline is becoming mo...
# 4     24th July 2024  ✅ Trip Verified |  3 out of 4 flights delayed ...
# ..               ...                                                ...
# 473   18th July 2011  JNB-NBO-JNB. This trip showed both the good an...
# 474   17th July 2011  Nairobi-London. Lounge in Nairobi was small an...
# 475   11th July 2011  Nairobi-London. As me and my wife are both whe...
# 476    6th July 2011  LUN-LLW in Economy. Adequate for a 1 hr trip. ...
# 477    4th July 2011  I fly Kenya very often (almost once every 2 we...
#
# [478 rows x 2 columns]

# %%
inspect_dataframe(df2)
# Out:
# ---- DataFrame Info ----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    478 non-null    object
#  1   Review  478 non-null    object
# dtypes: object(2)
# memory usage: 7.6+ KB
#
#
# ---- DataFrame Shape ----
# Rows: 478, Columns: 2
#
#
# ---- Missing Values ----
# Series([], dtype: int64)
#
#
# ---- Duplicate Rows ----
# Number of duplicate rows: 1

# %%
# Dropping the duplicate rows
df2 = df2.drop_duplicates()
df2.reset_index(drop=True, inplace=True)

df2
# Out:
#                 Date                                             Review
# 0    3rd August 2024  ✅ Trip Verified | I have never seen such a dis...
# 1    2nd August 2024  Not Verified |   Bumped off flight at boarding...
# 2     30th July 2024  ✅ Trip Verified |   I am disappointment with t...
# 3     25th July 2024  ✅ Trip Verified |  This airline is becoming mo...
# 4     24th July 2024  ✅ Trip Verified |  3 out of 4 flights delayed ...
# ..               ...                                                ...
# 472   18th July 2011  JNB-NBO-JNB. This trip showed both the good an...
# 473   17th July 2011  Nairobi-London. Lounge in Nairobi was small an...
# 474   11th July 2011  Nairobi-London. As me and my wife are both whe...
# 475    6th July 2011  LUN-LLW in Economy. Adequate for a 1 hr trip. ...
# 476    4th July 2011  I fly Kenya very often (almost once every 2 we...
#
# [477 rows x 2 columns]

# %%
df2.sample(10)
# Out:
#                    Date                                             Review
# 330   4th December 2014  Recently flew from LHR to Nairobi on to Kilima...
# 9        27th June 2024  ✅ Trip Verified |  One of the worst flights i ...
# 349       2nd June 2014  Travelled on KQ from Nairobi to Bangkok in eco...
# 324   14th January 2015  Flew from Paris via Amsterdam to Nairobi. The ...
# 394    9th October 2012  I found the flight horrible. My partners T.V d...
# 127     21st March 2021  ✅ Trip Verified | This was not my first time f...
# 51       27th July 2023  ✅ Trip Verified | Do not use Kenya Airways! Th...
# 46     22nd August 2023  Not Verified | Airline was 1 hour late to boar...
# 182      27th July 2019  Not Verified |  New York to Dar es Saalam via ...
# 426  15th February 2012  NBO-AMS. Checked in on-line baggage drop very ...

# %%
from datetime import datetime

# Function to remove ordinal suffixes
def remove_ordinal_suffix(date_str):
    return date_str.replace('st', '').replace('nd', '').replace('rd', '').replace('th', '')

# Apply the function to remove suffixes
df2['Date'] = df2['Date'].apply(remove_ordinal_suffix)

# Convert to datetime with errors='coerce'
df2['Date'] = pd.to_datetime(df2['Date'], format='%d %B %Y', errors='coerce')

df2
# Out:
# C:\Users\JEREMY\AppData\Local\Temp\ipykernel_54792\843626717.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date'] = df2['Date'].apply(remove_ordinal_suffix)
# C:\Users\JEREMY\AppData\Local\Temp\ipykernel_54792\843626717.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date'] = pd.to_datetime(df2['Date'], format='%d %B %Y', errors='coerce')
#           Date                                             Review
# 0          NaT  ✅ Trip Verified | I have never seen such a dis...
# 1          NaT  Not Verified |   Bumped off flight at boarding...
# 2   2024-07-30  ✅ Trip Verified |   I am disappointment with t...
# 3   2024-07-25  ✅ Trip Verified |  This airline is becoming mo...
# 4   2024-07-24  ✅ Trip Verified |  3 out of 4 flights delayed ...
# ..         ...                                                ...
# 472 2011-07-18  JNB-NBO-JNB. This trip showed both the good an...
# 473 2011-07-17  Nairobi-London. Lounge in Nairobi was small an...
# 474 2011-07-11  Nairobi-London. As me and my wife are both whe...
# 475 2011-07-06  LUN-LLW in Economy. Adequate for a 1 hr trip. ...
# 476 2011-07-04  I fly Kenya very often (almost once every 2 we...
#
# [477 rows x 2 columns]

# %%
placeholder_date = pd.to_datetime('24.02.2024', format='%d.%m.%Y')

# Replace NaT values with the placeholder date
df2['Date3'] = df2['Date'].fillna(placeholder_date)

df2
# Out:
# C:\Users\JEREMY\AppData\Local\Temp\ipykernel_54792\3552791828.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date3'] = df2['Date'].fillna(placeholder_date)
#           Date                                             Review      Date3
# 0          NaT  ✅ Trip Verified | I have never seen such a dis... 2024-02-24
# 1          NaT  Not Verified |   Bumped off flight at boarding... 2024-02-24
# 2   2024-07-30  ✅ Trip Verified |   I am disappointment with t... 2024-07-30
# 3   2024-07-25  ✅ Trip Verified |  This airline is becoming mo... 2024-07-25
# 4   2024-07-24  ✅ Trip Verified |  3 out of 4 flights delayed ... 2024-07-24
# ..         ...                                                ...        ...
# 472 2011-07-18  JNB-NBO-JNB. This trip showed both the good an... 2011-07-18
# 473 2011-07-17  Nairobi-London. Lounge in Nairobi was small an... 2011-07-17
# 474 2011-07-11  Nairobi-London. As me and my wife are both whe... 2011-07-11
# 475 2011-07-06  LUN-LLW in Economy. Adequate for a 1 hr trip. ... 2011-07-06
# 476 2011-07-04  I fly Kenya very often (almost once every 2 we... 2011-07-04
#
# [477 rows x 3 columns]

# %%
# Set the 'Date' column as the index
df2.set_index('Date3', inplace=True)

df2
# Out:
#                  Date                                             Review
# Date3
# 2024-02-24        NaT  ✅ Trip Verified | I have never seen such a dis...
# 2024-02-24        NaT  Not Verified |   Bumped off flight at boarding...
# 2024-07-30 2024-07-30  ✅ Trip Verified |   I am disappointment with t...
# 2024-07-25 2024-07-25  ✅ Trip Verified |  This airline is becoming mo...
# 2024-07-24 2024-07-24  ✅ Trip Verified |  3 out of 4 flights delayed ...
# ...               ...                                                ...
# 2011-07-18 2011-07-18  JNB-NBO-JNB. This trip showed both the good an...
# 2011-07-17 2011-07-17  Nairobi-London. Lounge in Nairobi was small an...
# 2011-07-11 2011-07-11  Nairobi-London. As me and my wife are both whe...
# 2011-07-06 2011-07-06  LUN-LLW in Economy. Adequate for a 1 hr trip. ...
# 2011-07-04 2011-07-04  I fly Kenya very often (almost once every 2 we...
#
# [477 rows x 2 columns]

# %%
df2 = df2.drop('Date', axis=1)

df2
# Out:
#                                                        Review
# Date3
# 2024-02-24  ✅ Trip Verified | I have never seen such a dis...
# 2024-02-24  Not Verified |   Bumped off flight at boarding...
# 2024-07-30  ✅ Trip Verified |   I am disappointment with t...
# 2024-07-25  ✅ Trip Verified |  This airline is becoming mo...
# 2024-07-24  ✅ Trip Verified |  3 out of 4 flights delayed ...
# ...                                                       ...
# 2011-07-18  JNB-NBO-JNB. This trip showed both the good an...
# 2011-07-17  Nairobi-London. Lounge in Nairobi was small an...
# 2011-07-11  Nairobi-London. As me and my wife are both whe...
# 2011-07-06  LUN-LLW in Economy. Adequate for a 1 hr trip. ...
# 2011-07-04  I fly Kenya very often (almost once every 2 we...
#
# [477 rows x 1 columns]

# %% [markdown]
# ## Dataset 3 - KQ_Reviews

# %%
df3 = pd.read_csv('KQ_Reviews.csv')
df3.sample(10)
# Out:
#                                       Heading  \
# 73                 I would avoid this airline
# 205    Uncaring, Unresponsive, Unimpressed!!!
# 83                 I travelled Business Class
# 55   I had to cancel my trip to Kenya (Kenya…
# 114              Used to be a fan not anymore
# 233     Kenya airways has arrogant staff and…
# 168   Incompetent customer service unable to…
# 58                            Booked a ticket
# 126    Hi when was at Heathrow had confirmed…
# 35         I’m so shocked they don’t have 5*…
#
#                                                   Body  Star Rating  \
# 73   I am strongly disappointed by this airline. Th...          NaN
# 205  For at least the last 5 days, their modify-boo...          1.0
# 83   I travelled Business Class, it was dreadful. C...          NaN
# 55   I had to cancel my trip to Kenya (Kenya Airway...          NaN
# 114  Used to be a fan not anymoreThey have lost my ...          1.0
# 233  Kenya airways has arrogant staff and arrogant ...          2.0
# 168  Incompetent customer service unable to resolve...          NaN
# 58   Booked a ticket, payed but never got the ticke...          NaN
# 126  Hi when was at Heathrow had confirmed all seat...          NaN
# 35   I’m so shocked that they do not have 5* review...          NaN
#
#                          Date
# 73   2023-01-25T08:39:05.000Z
# 205  2020-05-29T13:06:56.000Z
# 83   2022-02-26T06:48:21.000Z
# 55   2023-12-04T12:26:55.000Z
# 114  2023-03-02T09:59:40.000Z
# 233  2018-05-05T17:02:46.000Z
# 168  2021-10-24T21:31:12.000Z
# 58   2023-03-31T11:30:49.000Z
# 126  2022-08-27T07:40:12.000Z
# 35   2023-04-07T13:04:45.000Z

# %%
inspect_dataframe(df3)
# Out:
# ---- DataFrame Info ----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Heading      244 non-null    object
#  1   Body         244 non-null    object
#  2   Star Rating  76 non-null     float64
#  3   Date         244 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 7.8+ KB
#
#
# ---- DataFrame Shape ----
# Rows: 244, Columns: 4
#
#
# ---- Missing Values ----
# Star Rating    168
# dtype: int64
#
#
# ---- Duplicate Rows ----
# Number of duplicate rows: 1

# %%
# Dropping the duplicate rows
df3 = df3.drop_duplicates()
df3.reset_index(drop=True, inplace=True)

df3
# Out:
#                                                Heading  \
# 0                         Constantly canceling flights
# 1               Kenya Airways canceled the flight and…
# 2    If your thinking of Kenya Airlines...think aga...
# 3                                  Worst airlines ever
# 4    We were trying to go to Nampula from Nairobi a...
# ..                                                 ...
# 238                             Better than I expected
# 239                      Request for immediate action.
# 240                                        Never again
# 241                   NEVER AGAIN - RUBISH COMPANY !!!
# 242                     Worse Customer service ever!!!
#
#                                                   Body  Star Rating  \
# 0    Kenya airlines canceled my flight mid my journ...          NaN
# 1    Kenya Airways canceled the flight and never re...          NaN
# 2    If your thinking of using this airline...RUN d...          NaN
# 3    Worst airlines ever, not friendly staff, no fl...          NaN
# 4    We were trying to go from Europe through Nairo...          NaN
# ..                                                 ...          ...
# 238  Much better service than I had expected - espe...          NaN
# 239  I have never had a night mare, until I used Ke...          NaN
# 240  Flew with Kenya airways last year in October.U...          NaN
# 241  We travelled to Zanzibar in October 2015. From...          1.0
# 242  Will never ever take this flight again, had th...          NaN
#
#                          Date
# 0    2024-08-02T17:39:56.000Z
# 1    2024-08-04T20:05:08.000Z
# 2    2024-07-30T21:23:34.000Z
# 3    2024-07-29T23:47:06.000Z
# 4    2024-07-25T09:20:16.000Z
# ..                        ...
# 238  2017-01-26T17:27:53.000Z
# 239  2016-08-30T16:52:59.000Z
# 240  2016-07-02T10:26:21.000Z
# 241  2015-11-21T22:19:18.081Z
# 242  2014-07-02T02:37:19.000Z
#
# [243 rows x 4 columns]

# %%
df3['Star Rating'] = df3['Star Rating'].fillna(0)
df3
# Out:
#                                                Heading  \
# 0                         Constantly canceling flights
# 1               Kenya Airways canceled the flight and…
# 2    If your thinking of Kenya Airlines...think aga...
# 3                                  Worst airlines ever
# 4    We were trying to go to Nampula from Nairobi a...
# ..                                                 ...
# 238                             Better than I expected
# 239                      Request for immediate action.
# 240                                        Never again
# 241                   NEVER AGAIN - RUBISH COMPANY !!!
# 242                     Worse Customer service ever!!!
#
#                                                   Body  Star Rating  \
# 0    Kenya airlines canceled my flight mid my journ...          0.0
# 1    Kenya Airways canceled the flight and never re...          0.0
# 2    If your thinking of using this airline...RUN d...          0.0
# 3    Worst airlines ever, not friendly staff, no fl...          0.0
# 4    We were trying to go from Europe through Nairo...          0.0
# ..                                                 ...          ...
# 238  Much better service than I had expected - espe...          0.0
# 239  I have never had a night mare, until I used Ke...          0.0
# 240  Flew with Kenya airways last year in October.U...          0.0
# 241  We travelled to Zanzibar in October 2015. From...          1.0
# 242  Will never ever take this flight again, had th...          0.0
#
#                          Date
# 0    2024-08-02T17:39:56.000Z
# 1    2024-08-04T20:05:08.000Z
# 2    2024-07-30T21:23:34.000Z
# 3    2024-07-29T23:47:06.000Z
# 4    2024-07-25T09:20:16.000Z
# ..                        ...
# 238  2017-01-26T17:27:53.000Z
# 239  2016-08-30T16:52:59.000Z
# 240  2016-07-02T10:26:21.000Z
# 241  2015-11-21T22:19:18.081Z
# 242  2014-07-02T02:37:19.000Z
#
# [243 rows x 4 columns]

# %%
# Convert the 'Date' column to datetime with errors='coerce'
df3['Date'] = pd.to_datetime(df3['Date'], errors='coerce')

# Combine day, month, and year into a single column in the format 'dd-mm-yyyy'
df3['Date3'] = df3['Date'].dt.strftime('%d-%m-%Y')

# Set the new column as the index
df3.set_index('Date3', inplace=True)

# Drop the original 'Date' column if no longer needed
df3.drop(columns='Date', inplace=True)

df3
# Out:
#                                                       Heading  \
# Date3
# 02-08-2024                       Constantly canceling flights
# 04-08-2024             Kenya Airways canceled the flight and…
# 30-07-2024  If your thinking of Kenya Airlines...think aga...
# 29-07-2024                                Worst airlines ever
# 25-07-2024  We were trying to go to Nampula from Nairobi a...
# ...                                                       ...
# 26-01-2017                             Better than I expected
# 30-08-2016                      Request for immediate action.
# 02-07-2016                                        Never again
# 21-11-2015                   NEVER AGAIN - RUBISH COMPANY !!!
# 02-07-2014                     Worse Customer service ever!!!
#
#                                                          Body  Star Rating
# Date3
# 02-08-2024  Kenya airlines canceled my flight mid my journ...          0.0
# 04-08-2024  Kenya Airways canceled the flight and never re...          0.0
# 30-07-2024  If your thinking of using this airline...RUN d...          0.0
# 29-07-2024  Worst airlines ever, not friendly staff, no fl...          0.0
# 25-07-2024  We were trying to go from Europe through Nairo...          0.0
# ...                                                       ...          ...
# 26-01-2017  Much better service than I had expected - espe...          0.0
# 30-08-2016  I have never had a night mare, until I used Ke...          0.0
# 02-07-2016  Flew with Kenya airways last year in October.U...          0.0
# 21-11-2015  We travelled to Zanzibar in October 2015. From...          1.0
# 02-07-2014  Will never ever take this flight again, had th...          0.0
#
# [243 rows x 3 columns]

# %%
df3['Review'] = df3['Heading'] + ' ' + df3['Body']
df3 = df3.drop(columns= ['Heading', 'Body'])
df3.head(5)
# Out:
#             Star Rating                                             Review
# Date3
# 02-08-2024          0.0  Constantly canceling flights Kenya airlines ca...
# 04-08-2024          0.0  Kenya Airways canceled the flight and… Kenya A...
# 30-07-2024          0.0  If your thinking of Kenya Airlines...think aga...
# 29-07-2024          0.0  Worst airlines ever Worst airlines ever, not f...
# 25-07-2024          0.0  We were trying to go to Nampula from Nairobi a...

# %%
df3.rename(columns={'Date3': 'Date', 'Star Rating': 'Rating'}, inplace=True)
df3.head(5)
# Out:
#             Rating                                             Review
# Date3
# 02-08-2024     0.0  Constantly canceling flights Kenya airlines ca...
# 04-08-2024     0.0  Kenya Airways canceled the flight and… Kenya A...
# 30-07-2024     0.0  If your thinking of Kenya Airlines...think aga...
# 29-07-2024     0.0  Worst airlines ever Worst airlines ever, not f...
# 25-07-2024     0.0  We were trying to go to Nampula from Nairobi a...

# %% [markdown]
# ## Merging the datasets

# %%
Cleaned_df1.sample(10)
# Out:
#                Departures           Class  \
# Date3
# 2018-05-01  International         Economy
# 2022-04-01  International         Economy
# 2019-11-01  International  Business Class
# 2020-01-01         Africa         Economy
# 2018-02-01  International         Economy
# 2019-07-01         Africa         Economy
# 2017-02-01         Africa         Economy
# 2019-09-01   North Africa         Economy
# 2017-03-01         Africa         Economy
# 2018-11-01  International         Economy
#
#                                                        Review  Rating_Value  \
# Date3
# 2018-05-01  Great service, good food and pleasant staff. G...           5.0
# 2022-04-01  The worst airline, my trip became the worst ni...           1.0
# 2019-11-01  We were booked in economy and used the biding ...           4.0
# 2020-01-01  Went nonstop from ZNZ to NBO and had a good fl...           4.0
# 2018-02-01  Missed connecting flight due to a few minutes ...           1.0
# 2019-07-01  Unfortunately we got off to a bad start with K...           3.0
# 2017-02-01  Kenya Airways has better entertainment than mo...           5.0
# 2019-09-01  They have a great time keeping and service exp...           5.0
# 2017-03-01  Took a flight from Entebbe to Nairobi and from...           4.0
# 2018-11-01  Totally loved  the flight to Nairobi - the fli...           3.0
#
#            Rating_Description
# Date3
# 2018-05-01          Excellent
# 2022-04-01               Poor
# 2019-11-01               Good
# 2020-01-01               Good
# 2018-02-01               Poor
# 2019-07-01            Average
# 2017-02-01          Excellent
# 2019-09-01          Excellent
# 2017-03-01               Good
# 2018-11-01            Average

# %%
df2.sample(10)
# Out:
#                                                        Review
# Date3
# 2011-07-25  NBO-FIH. Check-in at the Jomo Kenyatta airport...
# 2018-06-10  ✅ Trip Verified |  Johannesburg to Kilimanjaro...
# 2024-02-24  ✅ Trip Verified |  I never thought I would exp...
# 2014-04-01  First time traveller with KA and returning wit...
# 2012-01-28  From Nairobi to Addis Ababa via Djibouti. I mu...
# 2011-09-13  Flights delayed. No customer service and poor ...
# 2021-11-09  ✅ Trip Verified | Wonderful service onboard th...
# 2018-10-27  ✅ Trip Verified |  Accra to Dar Es Salaam via ...
# 2014-05-26  MBA-NBO-CAN-NBO-MBA.. 1st leg was an Embraer E...
# 2021-06-20  ✅ Trip Verified |  It's our first time booking...

# %%
df3.sample(10)
# Out:
# c:\Users\JEREMY\anaconda3\Lib\site-packages\IPython\core\displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#             Rating                                             Review
# Date3
# 09-10-2021     0.0  Avoid, if possible! One and only experience wi...
# 29-08-2022     1.0  Kenya airways is the worst Airline you… Kenya ...
# 01-01-2024     0.0  A disaster, delay of 24h without explanation A...
# 08-01-2019     0.0  Kenya Airways – Factor in Ransom Payments I wa...
# 06-07-2019     0.0  Wonderful experience Wonderful experience, tra...
# 14-04-2021     0.0  Mis sold Mis sold. Told we can rebook before 2...
# 26-07-2023     4.0  Refund We had booked a bussines ticket last No...
# 03-08-2023     0.0  Disappointing Experience - Inflexible Name Cha...
# 25-07-2024     0.0  We were trying to go to Nampula from Nairobi a...
# 24-03-2024     1.0  Bad airline ,no respect for clients The flight...

# %%
# Concatenate cleaned_df1 and df2 by rows
concatenated_df = pd.concat([Cleaned_df1, df2], axis=0)

concatenated_df
# Out:
#                Departures           Class  \
# Date3
# 2022-09-01         Africa         Economy
# 2022-11-01  International         Economy
# 2022-05-01  International         Economy
# 2022-11-01         Africa  Business Class
# 2022-11-01         Africa         Economy
# ...                   ...             ...
# 2011-07-18            NaN             NaN
# 2011-07-17            NaN             NaN
# 2011-07-11            NaN             NaN
# 2011-07-06            NaN             NaN
# 2011-07-04            NaN             NaN
#
#                                                        Review  Rating_Value  \
# Date3
# 2022-09-01  Recently I travelled for business from Cape To...           4.0
# 2022-11-01  I want to thanks to Jane for her excellent ser...           5.0
# 2022-05-01  not a bad airline to fly with could do with a ...           4.0
# 2022-11-01  Dear Kenya Airways ,\n\nI am on my way to Zanz...           1.0
# 2022-11-01  Absolutely appalling airline, never ever use i...           1.0
# ...                                                       ...           ...
# 2011-07-18  JNB-NBO-JNB. This trip showed both the good an...           NaN
# 2011-07-17  Nairobi-London. Lounge in Nairobi was small an...           NaN
# 2011-07-11  Nairobi-London. As me and my wife are both whe...           NaN
# 2011-07-06  LUN-LLW in Economy. Adequate for a 1 hr trip. ...           NaN
# 2011-07-04  I fly Kenya very often (almost once every 2 we...           NaN
#
#            Rating_Description
# Date3
# 2022-09-01               Good
# 2022-11-01          Excellent
# 2022-05-01               Good
# 2022-11-01               Poor
# 2022-11-01               Poor
# ...                       ...
# 2011-07-18                NaN
# 2011-07-17                NaN
# 2011-07-11                NaN
# 2011-07-06                NaN
# 2011-07-04                NaN
#
# [2822 rows x 5 columns]

# %%
concatenated_df.rename(columns={'Rating_Value': 'Rating'}, inplace=True)
concatenated_df.head(5)
# Out:
#                Departures           Class  \
# Date3
# 2022-09-01         Africa         Economy
# 2022-11-01  International         Economy
# 2022-05-01  International         Economy
# 2022-11-01         Africa  Business Class
# 2022-11-01         Africa         Economy
#
#                                                        Review  Rating  \
# Date3
# 2022-09-01  Recently I travelled for business from Cape To...     4.0
# 2022-11-01  I want to thanks to Jane for her excellent ser...     5.0
# 2022-05-01  not a bad airline to fly with could do with a ...     4.0
# 2022-11-01  Dear Kenya Airways ,\n\nI am on my way to Zanz...     1.0
# 2022-11-01  Absolutely appalling airline, never ever use i...     1.0
#
#            Rating_Description
# Date3
# 2022-09-01               Good
# 2022-11-01          Excellent
# 2022-05-01               Good
# 2022-11-01               Poor
# 2022-11-01               Poor

# %%
# Concatenate concatenated_df and df3 by rows
Final_df = pd.concat([concatenated_df, df3], axis=0)

Final_df
# Out:
#                         Departures           Class  \
# Date3
# 2022-09-01 00:00:00         Africa         Economy
# 2022-11-01 00:00:00  International         Economy
# 2022-05-01 00:00:00  International         Economy
# 2022-11-01 00:00:00         Africa  Business Class
# 2022-11-01 00:00:00         Africa         Economy
# ...                            ...             ...
# 26-01-2017                     NaN             NaN
# 30-08-2016                     NaN             NaN
# 02-07-2016                     NaN             NaN
# 21-11-2015                     NaN             NaN
# 02-07-2014                     NaN             NaN
#
#                                                                 Review  \
# Date3
# 2022-09-01 00:00:00  Recently I travelled for business from Cape To...
# 2022-11-01 00:00:00  I want to thanks to Jane for her excellent ser...
# 2022-05-01 00:00:00  not a bad airline to fly with could do with a ...
# 2022-11-01 00:00:00  Dear Kenya Airways ,\n\nI am on my way to Zanz...
# 2022-11-01 00:00:00  Absolutely appalling airline, never ever use i...
# ...                                                                ...
# 26-01-2017           Better than I expected Much better service tha...
# 30-08-2016           Request for immediate action. I have never had...
# 02-07-2016           Never again Flew with Kenya airways last year ...
# 21-11-2015           NEVER AGAIN - RUBISH COMPANY !!! We travelled ...
# 02-07-2014           Worse Customer service ever!!! Will never ever...
#
#                      Rating Rating_Description
# Date3
# 2022-09-01 00:00:00     4.0               Good
# 2022-11-01 00:00:00     5.0          Excellent
# 2022-05-01 00:00:00     4.0               Good
# 2022-11-01 00:00:00     1.0               Poor
# 2022-11-01 00:00:00     1.0               Poor
# ...                     ...                ...
# 26-01-2017              0.0                NaN
# 30-08-2016              0.0                NaN
# 02-07-2016              0.0                NaN
# 21-11-2015              1.0                NaN
# 02-07-2014              0.0                NaN
#
# [3065 rows x 5 columns]
